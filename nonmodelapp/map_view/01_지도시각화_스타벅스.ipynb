# %%
"""
< 라이브러리(패키지) 설치 방법 >
1. conda 명령으로 설치
 > conda install -c conda-forge 패키지명==버전   # 특별한 경우 아니면 버전 안써도 됨
 또는
 > conda install 모듈명==버전

2. pip 명령으로 설치
 > pip install 모듈명=버전
"""
# Out:
# '\n< 라이브러리(패키지) 설치 방법 >\n1. conda 명령으로 설치\n > conda install -c conda-forge 패키지명==버전   # 특별한 경우 아니면 버전 안써도 됨\n 또는\n > conda install 모듈명==버전\n\n2. pip 명령으로 설치\n > pip install 모듈명=버전\n'

# %%
### 행렬데이터 처리 라이브러리
import pandas as pd

### 사용하는 라이브러리(패키지)
# - install 해야 사용가능
# conda install -c conda-forge folium
import folium

# %%
### 데이터 읽어들이기
# - 데이터프레임명 : seoul_starbucks

file_path = "./4_4_seoul_starbucks_list.xlsx"
seoul_starbucks = pd.read_excel(file_path)
seoul_starbucks
# Out:
#           매장명         위도          경도     매장타입
# 0     역삼아레나빌딩  37.501087  127.043069  general  \
# 1      논현역사거리  37.510178  127.022223  general
# 2      국기원사거리  37.499517  127.031495  general
# 3     대치대원빌딩R  37.494668  127.062583  reserve
# 4    삼성역섬유센터R  37.507750  127.060651  reserve
# ..        ...        ...         ...      ...
# 496       중랑역  37.593033  127.074736  general
# 497      중랑구청  37.605389  127.095756  general
# 498      사가정역  37.579594  127.087966  general
# 499       상봉역  37.596890  127.086470  general
# 500     묵동이마트  37.613433  127.077484  general
#
#                                     주소          전화번호 시군구명
# 0              서울특별시 강남구 언주로 425 (역삼동)   02-568-3762  강남구
# 1             서울특별시 강남구 강남대로 538 (논현동)  02-3442-3672  강남구
# 2             서울특별시 강남구 테헤란로 125 (역삼동)   02-568-3668  강남구
# 3           서울특별시 강남구 남부순환로 2947 (대치동)   02-568-3704  강남구
# 4             서울특별시 강남구 테헤란로 518 (대치동)   02-568-3648  강남구
# ...

# %%
seoul_starbucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장명     501 non-null    object
#  1   위도      501 non-null    float64
#  2   경도      501 non-null    float64
#  3   매장타입    501 non-null    object
#  4   주소      501 non-null    object
#  5   전화번호    501 non-null    object
#  6   시군구명    501 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 27.5+ KB

# %%
seoul_starbucks.describe()
# Out:
#                위도          경도
# count  501.000000  501.000000
# mean    37.537883  126.993372
# std      0.040095    0.072150
# min     37.447323  126.816415
# 25%     37.505321  126.934694
# 50%     37.535149  126.992455
# 75%     37.564064  127.042165
# max     37.660941  127.174258

# %% [markdown]
# # 지도시각화

# %%
### 사용하는 라이브러리(패키지) : folium

# %% [markdown]
# ##### 지도 map 그리기

# %%
starbucks_map = folium.Map(
    ### 최초에 보여줄 지도의 중심위치(위/경도) 지정
    # - 서울 중심점
    location = [37.573050, 126.979189], 
    
    ### 지도 스타일 지정하기
    # 도시형 건물 스타일 지정(가장 일반적 스타일)
    tiles = "openstreetmap",
    
    ### 최초에 보여줄 zoom 사이즈 지정하기
    zoom_start = 50
)

# %%
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##### 지도 위에 마커 표시하기

# %%
seoul_starbucks
# Out:
#           매장명         위도          경도     매장타입
# 0     역삼아레나빌딩  37.501087  127.043069  general  \
# 1      논현역사거리  37.510178  127.022223  general
# 2      국기원사거리  37.499517  127.031495  general
# 3     대치대원빌딩R  37.494668  127.062583  reserve
# 4    삼성역섬유센터R  37.507750  127.060651  reserve
# ..        ...        ...         ...      ...
# 496       중랑역  37.593033  127.074736  general
# 497      중랑구청  37.605389  127.095756  general
# 498      사가정역  37.579594  127.087966  general
# 499       상봉역  37.596890  127.086470  general
# 500     묵동이마트  37.613433  127.077484  general
#
#                                     주소          전화번호 시군구명
# 0              서울특별시 강남구 언주로 425 (역삼동)   02-568-3762  강남구
# 1             서울특별시 강남구 강남대로 538 (논현동)  02-3442-3672  강남구
# 2             서울특별시 강남구 테헤란로 125 (역삼동)   02-568-3668  강남구
# 3           서울특별시 강남구 남부순환로 2947 (대치동)   02-568-3704  강남구
# 4             서울특별시 강남구 테헤란로 518 (대치동)   02-568-3648  강남구
# ...

# %%
### 위/경도 데이터를 추출하여 마커 표시하기
# 반복하면서 위/경도 출력하기
# 위도 : lat, 경도 : lng

# 내가 한거
#lat = []
#lng = []

#for k in range(len(seoul_starbucks)) :
#    lat.append(seoul_starbucks['위도'][k])
#    lng.append(seoul_starbucks['경도'][k])
    
#print(lat)
#print(lng)


# 강사님
for idx in seoul_starbucks.index :           
    lat = seoul_starbucks.loc[idx, "위도"]
    lng = seoul_starbucks.loc[idx, "경도"]
    
    ### 지도에 표시할 마킹 모양 등 스타일 지정
    folium.CircleMarker(
        # 마커의 위치 지정 : 위도, 경도
        location = [lat, lng],
        # 마커 채우기 색상
        fill_color = 'green',
        # 마커 투명도(0~1)
        fill_opacity = 1,
        # 마커 테두리 색상
        color = 'yellow',
        # 마커 테두리 두께
        weight = 1,
        # 마커 크기
        radius = 5  
    ).add_to(starbucks_map)

# %%
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
seoul_starbucks
# Out:
#           매장명         위도          경도     매장타입
# 0     역삼아레나빌딩  37.501087  127.043069  general  \
# 1      논현역사거리  37.510178  127.022223  general
# 2      국기원사거리  37.499517  127.031495  general
# 3     대치대원빌딩R  37.494668  127.062583  reserve
# 4    삼성역섬유센터R  37.507750  127.060651  reserve
# ..        ...        ...         ...      ...
# 496       중랑역  37.593033  127.074736  general
# 497      중랑구청  37.605389  127.095756  general
# 498      사가정역  37.579594  127.087966  general
# 499       상봉역  37.596890  127.086470  general
# 500     묵동이마트  37.613433  127.077484  general
#
#                                     주소          전화번호 시군구명
# 0              서울특별시 강남구 언주로 425 (역삼동)   02-568-3762  강남구
# 1             서울특별시 강남구 강남대로 538 (논현동)  02-3442-3672  강남구
# 2             서울특별시 강남구 테헤란로 125 (역삼동)   02-568-3668  강남구
# 3           서울특별시 강남구 남부순환로 2947 (대치동)   02-568-3704  강남구
# 4             서울특별시 강남구 테헤란로 518 (대치동)   02-568-3648  강남구
# ...

# %%
seoul_starbucks['매장타입'].unique()
# Out:
# array(['general', 'reserve', 'generalDT'], dtype=object)

# %%
starbucks_map2 = folium.Map(
    ### 최초에 보여줄 지도의 중심위치(위/경도) 지정
    # - 서울 중심점
    location = [37.573050, 126.979189], 
    
    ### 지도 스타일 지정하기
    # 도시형 건물 스타일 지정(가장 일반적 스타일)
    tiles = "openstreetmap",
    
    ### 최초에 보여줄 zoom 사이즈 지정하기
    zoom_start = 50
)

# %%
starbucks_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
### 매장 타입별로 마커 색상과 사이즈를 달리해서 지도에 표시하기
# general : green, 크기 : 3
# reserve : blue, 크기 : 5
# DT : red, 크기 : 5

# %%
starbucks_map2 = folium.Map(
    ### 최초에 보여줄 지도의 중심위치(위/경도) 지정
    # - 서울 중심점
    location = [37.573050, 126.979189], 
    
    ### 지도 스타일 지정하기
    ### 도시형 건물 스타일 지정(가장 일반적 스타일) : openstreetmap
    ### 산림 위주의 스타일 : Stamen Terrain
    ### 하천이나 도로 위주 스타일 : cartodbpositron
    tiles = "openstreetmap",
    
    ### 최초에 보여줄 zoom 사이즈 지정하기
    zoom_start = 50
)

for idx in seoul_starbucks.index :           
    lat = seoul_starbucks.loc[idx, "위도"]
    lng = seoul_starbucks.loc[idx, "경도"]
    s_type = seoul_starbucks.loc[idx, "매장타입"]
    
    f_color = ""
    size = 1
    
    if s_type == "general" :
        f_color = 'green'
        size = 3
    elif s_type == 'reserve' :
        f_color = 'blue'
        size = 5
    else :
        f_color = 'red'
        size = 5
    
    ### 지도에 표시할 마킹 모양 등 스타일 지정
    folium.CircleMarker(
        # 마커의 위치 지정 : 위도, 경도
        location = [lat, lng],
        # 마커 채우기 색상
        fill_color = f_color,
        # 마커 투명도(0~1)
        fill_opacity = 1,
        # 마커 테두리 색상
        color = 'yellow',
        # 마커 테두리 두께
        weight = 1,
        # 마커 크기
        radius = size  
    ).add_to(starbucks_map2)

# %%
starbucks_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
